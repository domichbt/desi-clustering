# %% [markdown]
# # Read data and randoms clustering catalogs
#
# **Aim:** Read data and randoms clustering catalogs with the expand and shuffling option for the randoms.
#
# **Important:** This code can be run with MPI without any modification (srun -n X python ... ).

# %%
# %load_ext autoreload
# %autoreload 2

## IMPORTANT: for now it works with cosmodesi environment and for internal uses only -> need to update this for public release.

# %%
import os
import sys
from pathlib import Path
import numpy as np

import logging
from mpytools import Catalog, setup_logging

sys.path.insert(0, '../')
from clustering_statistics.tools import read_clustering_catalog, get_catalog_fn, propose_fiducial

from mpi4py import MPI
mpicomm = MPI.COMM_WORLD

# disable jax warning:
logging.getLogger("jax._src.xla_bridge").setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

setup_logging(level=(logging.INFO if mpicomm.rank == 0 else logging.ERROR))
# Out:
# <module 'clustering_statistics' from '/global/u2/a/adematti/cosmodesi/desi-clustering/nb/../clustering_statistics/__init__.py'>

# %% [markdown]
# Let's have a look to the GLAM Mocks !

# %%
# region = NGC, SGC, ALL (NGC+SGC), ... 
attrs = {'version': 'glam-uchuu-v1-altmtl', 'tracer': 'QSO', 'region': 'ALL', 'imock': 100}

# Different analysis are using different fiducial choices:
fiducial = propose_fiducial('catalog', tracer=attrs['tracer'], analysis='full_shape')
attrs.update(fiducial) 
print('Fiducial choice for catalog (Full Shape):', fiducial)
fiducial_png = propose_fiducial('catalog', tracer=attrs['tracer'], analysis='local_png')
print('Fiducial choice for catalog (Local PNG):', fiducial_png)

## For speed reason reduce the number of randoms for this demo:
attrs['nran'] = 1

print('')
print('data are located: ', get_catalog_fn(kind='data', **attrs))
print('randoms are located: ', get_catalog_fn(kind='randoms', **attrs))
# Out:
# Fiducial choice for catalog (Full Shape): {'weight': 'default-FKP', 'nran': 4, 'zranges': [(0.8, 2.1)], 'FKP_P0': 6000.0}
# Fiducial choice for catalog (Local PNG): {'weight': 'default-fkp-oqe', 'nran': 4, 'zranges': [(0.8, 3.5), (0.8, 1.1), (0.8, 1.6)], 'FKP_P0': 30000.0}
#
# data are located:  [PosixPath('/dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5'), PosixPath('/dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5')]
# randoms are located:  [(PosixPath('/dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_0_clustering.ran.h5'), PosixPath('/dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_0_clustering.ran.h5'))]

# %%
help(get_catalog_fn)
# Out:
# Help on function get_catalog_fn in module clustering_statistics.tools:
#
# get_catalog_fn(version=None, cat_dir=None, kind='data', tracer='LRG', region='NGC', weight='default-FKP', nran=10, imock=0, ext='h5', **kwargs)
#     Return catalog file name(s) for given parameters.
#
#     Parameters
#     ----------
#     version : str
#         Catalog version. Options are 'data-dr1-v1.5', 'data-dr2-v2', 'holi-v1-complete', 'holi-v1-altmtl'.
#     cat_dir : str, Path, optional
#         Directory containing the catalogs. If None, pre-registered paths will be used based on version.
#     kind : str
#         Catalog kind. Options are 'data', 'randoms', 'full_data', 'full_randoms'.
#     tracer : str
#         Tracer name. Options are 'BGS', 'LRG', 'ELG', 'LRG+ELG', 'QSO'.
#     region : str
#         Region name. Options are 'NGC', 'SGC', 'N', 'S', 'ALL', 'NGCnoN', 'SGCnoDES'.
#     weight : str
#         Weight type. Options are 'default-FKP', 'defaut-bitwise-FKP', etc.
#     nran : int, list
#         Number of random catalogs.
#         If a list, return this specific random catalog.
#     imock : int
#         Mock index (for mock catalogs). Default is 0.
#     ext : str
#         File extension. Default is 'h5'.
#         Pass ``None`` to try to guess it.
#
#     Returns
#     -------
#     fn : Path, list
#         Catalog file name(s).
#         Multiple file names are returned as a list when region is 'ALL' or when kind is 'randoms' or 'full_randoms', or imock is '*'.

# %%
print('Reading data catalog...')
print(Catalog.read(get_catalog_fn(kind='data', **attrs), group='LSS', locking=False, mpicomm=mpicomm))
print('Reading randoms catalog...')
fns = get_catalog_fn(kind='randoms', **attrs)  # a list (each of nran randoms) of tuple of file names ('NGC', 'SGC')
fns = [ff for fn in fns for ff in fn]  # flatten
print(Catalog.read(fns, group='LSS', locking=False, mpicomm=mpicomm))

print('')
print('Randoms do not contain all the expected columns. This is for memory reason, we do not write and save RA, DEC, Z,... that are the same for all the mock realisations.')
print('We are providing a way to read the catalogs with read_clustering_catalog function.')
print('')
# Out:
# Reading data catalog...
# [000189.10] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5.
# [000189.11] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5.
# Catalog(csize=2022651, size=2022651, columns=['DEC', 'FRAC_TLOBS_TILES', 'NTILE', 'NX', 'PHOTSYS', 'RA', 'TARGETID', 'TILEID', 'WEIGHT', 'WEIGHT_COMP', 'WEIGHT_FKP', 'WEIGHT_IMLIN', 'WEIGHT_SYS', 'WEIGHT_ZFAIL', 'Z'])
# Reading randoms catalog...
# [000189.12] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_0_clustering.ran.h5.
# [000189.12] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_0_clustering.ran.h5.
# Catalog(csize=27929969, size=27929969, columns=['NX', 'TARGETID', 'TARGETID_DATA', 'WEIGHT'])
#
# Randoms do not contain all the expected columns. This is for memory reason, we do not write and save RA, DEC, Z,... that are the same for all the mock realisations.
# We are providing a way to read the catalogs with read_clustering_catalog function.

# %%
expand = {'parent_randoms_fn': get_catalog_fn(kind='parent_randoms', version='data-dr2-v2', tracer=attrs['tracer'], nran=attrs['nran'])}
randoms = read_clustering_catalog(kind='randoms', expand=expand, mpicomm=mpicomm, **attrs) 
print(randoms)
# Out:
# [000198.04] [0/1] 03-19 11:44  tools                     INFO     Expanding randoms
# [000198.04] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/survey/catalogs/DA2/LSS/loa-v1/LSScats/v2/dark_0_full_noveto.ran.h5.
# [000198.17] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5.
# [000198.17] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5.
# [000198.18] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_0_clustering.ran.h5.
# [000198.18] [0/1] 03-19 11:44  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_0_clustering.ran.h5.
# /global/u2/a/adematti/cosmodesi/desi-clustering/nb/../clustering_statistics/tools.py:1105: UserWarning: WEIGHT not in catalog
#   warnings.warn('WEIGHT not in catalog')
# [000213.75] [0/1] 03-19 11:45  tools                     INFO     Multiplying individual weights by FKP weight computed with FKP_P0 = 6000.0
# Catalog(csize=27929969, size=27929969, columns=['RA', 'DEC', 'Z', 'NX', 'TARGETID', 'INDWEIGHT', 'POSITION'])

# %%
# Let's have a look to the weight columns called INDWEIGHT (for individual weights):
data = read_clustering_catalog(kind='data', keep_columns=True, mpicomm=mpicomm, **attrs)
print(attrs['weight'], data) 

# First compute the mean completeness weight as a function of 'NTILE'
from clustering_statistics.tools import  _compute_binned_weight
weight_ntl = _compute_binned_weight(data['NTILE'], data['WEIGHT_COMP'])[data['NTILE']] 
# Compute the total weights:
weight = data['WEIGHT_COMP'] * data['WEIGHT_SYS'] * data['WEIGHT_ZFAIL'] / weight_ntl

# For mocks, the result is not exactly the same because of the float compression in the mock files.
print('Without FKP weights:')
print(data['WEIGHT'])
print(weight)

print('With FKP weights:')
print(data['INDWEIGHT'])
print(weight * data['WEIGHT_FKP'])
# Out:
# [000223.69] [0/1] 03-19 11:45  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5.
# [000223.73] [0/1] 03-19 11:45  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5.
# [000223.77] [0/1] 03-19 11:45  tools                     INFO     Multiplying individual weights by FKP weight computed with FKP_P0 = 6000.0
# default-FKP Catalog(csize=1344031, size=1344031, columns=['RA', 'DEC', 'Z', 'WEIGHT', 'WEIGHT_COMP', 'WEIGHT_FKP', 'WEIGHT_SYS', 'WEIGHT_ZFAIL', 'FRAC_TLOBS_TILES', 'NTILE', 'NX', 'TARGETID', 'INDWEIGHT', 'POSITION'])
# Without FKP weights:
# [1.64160156 0.82080078 0.83007812 ... 0.96044922 0.95654297 0.95898438]
# [1.64132121 0.82025252 0.83004658 ... 0.96060227 0.95685358 0.95919651]
# With FKP weights:
# [1.44474594 0.72123795 0.76245471 ... 0.80644061 0.80123595 0.81425741]
# [1.44449921 0.72075619 0.76242574 ... 0.80656912 0.80149613 0.81443753]
# [000169.33] [0/1] 03-05 16:58  tools                     INFO     Multiplying individual weights by FKP weight computed with FKP_P0 = 6000.0
# default-FKP Catalog(csize=2022651, size=2022651, columns=['RA', 'DEC', 'Z', 'WEIGHT', 'WEIGHT_COMP', 'WEIGHT_FKP', 'WEIGHT_SYS', 'WEIGHT_ZFAIL', 'FRAC_TLOBS_TILES', 'NTILE', 'NX', 'TARGETID', 'INDWEIGHT', 'POSITION'])
# Without FKP weights:
# [1.64160156 0.82080078 0.83007812 ... 0.97412109 0.97607422 0.96533203]
# [1.64237141 0.82077736 0.83057769 ... 0.97456491 0.97643908 0.9651941 ]
# With FKP weights:
# [1.44474594 0.72123795 0.76245471 ... 0.81816587 0.83613109 0.81396232]
# [1.44542348 0.72121737 0.76291358 ... 0.81853864 0.83644364 0.81384601]

# %% [markdown]
# ## On-the-fly reshuffling

# %%
# For the mocks, you can also reshuffle randoms on the fly (this is slow without MPI), especially to test RIC.

# First, pass expand if randoms do not have RA, DEC, and NTILE columns:
expand = {'parent_randoms_fn': get_catalog_fn(kind='parent_randoms', version='data-dr2-v2', tracer=attrs['tracer'], nran=attrs['nran'])}

# Then provide directory to merged data catalogs (we will draw the redshift from the concatenates mock data catalogs, removing the effect of RIC)
merged_dir = Path('/dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/desipipe/') /  attrs['version'] / 'merged'
merged_data_fn = get_catalog_fn(kind='data', cat_dir=merged_dir, **(attrs | dict(region='ALL')))
merged_data_fn = get_catalog_fn(kind='data', **(attrs | dict(region='ALL')))
reshuffle = {'merged_data_fn': merged_data_fn}
randoms_reshuffled = read_clustering_catalog(kind='randoms', expand=expand, reshuffle=reshuffle, mpicomm=mpicomm, **attrs) 
print(randoms_reshuffled)
# Out:
# [001071.16] [0/1] 03-19 11:59  tools                     INFO     Expanding randoms
# [001071.17] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/survey/catalogs/DA2/LSS/loa-v1/LSScats/v2/dark_0_full_noveto.ran.h5.
# [001071.30] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5.
# [001071.30] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5.
# [001071.30] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5.
# [001071.31] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5.
# [001071.31] [0/1] 03-19 11:59  tools                     INFO     Reshuffling randoms
# [001071.31] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_clustering.dat.h5.
# [001071.31] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_clustering.dat.h5.
# [001071.32] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_NGC_0_clustering.ran.h5.
# [001071.32] [0/1] 03-19 11:59  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl100/loa-v1/mock100/LSScats/QSO_SGC_0_clustering.ran.h5.
# [001084.51] [0/1] 03-19 11:59  tools                     INFO     Reshuffling randoms started.
# /global/u2/a/adematti/cosmodesi/desi-clustering/nb/../clustering_statistics/tools.py:2014: UserWarning: FRAC_TLOBS_TILES not in randoms, but it isn't trivially one in the data; the reshuffled randoms will most likely not match the data
#   warnings.warn(f"{column} not in randoms, but it isn't trivially one in the data; the reshuffled randoms will most likely not match the data")
# [001088.62] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001089.29] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001091.01] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001092.71] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001093.35] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001095.04] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001096.21] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001098.34] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001102.44] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001103.06] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001104.92] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001105.55] [0/1] 03-19 11:59  Footprint                 INFO     Load DR9 footprint with nside=256, mask_lmc=False, clear_south=True, mask_around_des=False and cut_desi=False
# [001107.20] [0/1] 03-19 11:59  tools                     INFO     alpha after renormalization & reweighting: [1.00091756 0.99978093 0.99953933]
# [001107.21] [0/1] 03-19 11:59  tools                     INFO     Reshuffling randoms completed in 22.7 s
# [001107.36] [0/1] 03-19 11:59  tools                     INFO     Multiplying individual weights by FKP weight computed with FKP_P0 = 6000.0
# Catalog(csize=27929969, size=27929969, columns=['RA', 'DEC', 'Z', 'NX', 'TARGETID', 'INDWEIGHT', 'POSITION'])

# %%
import matplotlib.pyplot as plt
hist_kws = dict(bins=50, histtype='step', density=True, lw=2)
plt.hist(data['Z'], weights=data['INDWEIGHT'], label='data', ls='-', **hist_kws)
plt.hist(randoms['Z'], weights=randoms['INDWEIGHT'], label='randoms', ls='--', **hist_kws)
plt.hist(randoms_reshuffled['Z'], weights=randoms_reshuffled['INDWEIGHT'], label='randoms (reshuffled)', ls=':', **hist_kws)
plt.xlabel('Redshift')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ## On-the-fly complete mocks
# It is possible to create completeness-weighted complete (i.e. "without fiber assignment") mocks.

# %%
# Define catalog options
tracer = 'LRG'
version = 'glam-uchuu-v1-altmtl'
catalog_options = dict(version=version, tracer=tracer, zrange=(0.8, 1.1), region='NGC', weight='default', imock=128, nran=2)

# Pass complete = {} to create a complete data catalog on-the-fly
# And reshuffle to store the new (complete) data catalog to resample redshifts from in cache
complete, reshuffle = {}, {}
data = read_clustering_catalog(kind='data', complete=complete, reshuffle=reshuffle, **catalog_options)
# Can be combined with expand
expand = {'parent_randoms_fn': get_catalog_fn(kind='parent_randoms', version='data-dr2-v2', tracer=tracer, nran=catalog_options['nran'])}
randoms = read_clustering_catalog(kind='randoms', complete=complete, reshuffle=reshuffle, expand=expand, **catalog_options)
# Out:
# [001117.05] [0/1] 03-19 12:00  tools                     INFO     On-the-fly complete data.
# [001117.06] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl128/loa-v1/mock128/LSScats/LRG_full_HPmapcut.dat.h5.
# [001117.07] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/forFA128.fits.
# /global/u2/a/adematti/cosmodesi/desi-clustering/nb/../clustering_statistics/tools.py:1105: UserWarning: WEIGHT not in catalog
#   warnings.warn('WEIGHT not in catalog')
# [001132.85] [0/1] 03-19 12:00  tools                     INFO     Reshuffling randoms to match on-the-fly complete data.
# [001132.85] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl128/loa-v1/mock128/LSScats/LRG_full_HPmapcut.dat.h5.
# [001132.86] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/forFA128.fits.
# [001145.56] [0/1] 03-19 12:00  tools                     INFO     Expanding randoms
# [001145.56] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/survey/catalogs/DA2/LSS/loa-v1/LSScats/v2/dark_0_full_noveto.ran.h5.
# [001145.70] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/survey/catalogs/DA2/LSS/loa-v1/LSScats/v2/dark_1_full_noveto.ran.h5.
# [001145.82] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl128/loa-v1/mock128/LSScats/LRG_NGC_0_clustering.ran.h5.
# [001145.82] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl128/loa-v1/mock128/LSScats/LRG_SGC_0_clustering.ran.h5.
# [001158.17] [0/1] 03-19 12:00  tools                     INFO     Reshuffling randoms started.
# [001165.96] [0/1] 03-19 12:00  tools                     INFO     alpha after renormalization & reweighting: [1.00016979 0.99996383]
# [001165.98] [0/1] 03-19 12:00  tools                     INFO     Reshuffling randoms completed in 7.8 s
# [001166.84] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl128/loa-v1/mock128/LSScats/LRG_NGC_1_clustering.ran.h5.
# [001166.85] [0/1] 03-19 12:00  FileStack                 INFO     Reading /dvs_ro/cfs/cdirs/desi/mocks/cai/LSS/DA2/mocks/GLAM-Uchuu_v1/altmtl128/loa-v1/mock128/LSScats/LRG_SGC_1_clustering.ran.h5.
# [001179.18] [0/1] 03-19 12:01  tools                     INFO     Reshuffling randoms started.
# [001187.09] [0/1] 03-19 12:01  tools                     INFO     alpha after renormalization & reweighting: [1.00023804 0.99994929]
# [001187.16] [0/1] 03-19 12:01  tools                     INFO     Reshuffling randoms completed in 8.0 s
